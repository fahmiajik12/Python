# %% [markdown]
# <a href="https://colab.research.google.com/github/fahmiajik12/machine-elearning/blob/Master/imgblend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import glob
import os.path
import numpy as np

# %%
path1 = "folder1/*.jpg"
path2 = "folder2/*.tif"

# %%
for file1,file2 in zip(glob.glob(path1), glob.glob(path2)):
    # e.g. MyPhoto.jpg
    basename = os.path.basename(file1)
    # e.g. MyPhoto
    name = os.path.splitext(basename)[0]

# %%
    #read img
    image_folder1 = cv2.imread(file1)
    image_folder2 = cv2.imread(file2)

# %%
    combine = cv2.add(image_folder1,image_folder2)
    cv2.imwrite('result/' + name + '.jpg', combine)#save
# Out:
# True

# %%
from google.colab.patches import cv2_imshow
data10 = cv2.imread('result/data10.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data10)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1E7410>

# %%
from google.colab.patches import cv2_imshow
data11 = cv2.imread('result/data11.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data11)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1C6F50>

# %%
from google.colab.patches import cv2_imshow
data12 = cv2.imread('result/data12.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data12)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1FDF90>

# %%
from google.colab.patches import cv2_imshow
data13 = cv2.imread('result/data13.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data13)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE2C6250>

# %%
from google.colab.patches import cv2_imshow
data14 = cv2.imread('result/data14.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data14)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE23D090>

# %%
from google.colab.patches import cv2_imshow
data15 = cv2.imread('result/data15.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data15)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1CC890>

# %%
from google.colab.patches import cv2_imshow
data16 = cv2.imread('result/data16.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data16)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE226B10>

# %%
from google.colab.patches import cv2_imshow
data17 = cv2.imread('result/data17.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data17)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1F1B90>

# %%
from google.colab.patches import cv2_imshow
data18 = cv2.imread('result/data18.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data18)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE2C6550>

# %%
from google.colab.patches import cv2_imshow
data19 = cv2.imread('result/data19.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data19)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1E7CD0>

# %%
from google.colab.patches import cv2_imshow
data20 = cv2.imread('result/data20.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data20)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1C6210>

# %%
from google.colab.patches import cv2_imshow
data21 = cv2.imread('result/data21.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data21)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE2391D0>

# %%
from google.colab.patches import cv2_imshow
data22 = cv2.imread('result/data22.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data22)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE235E50>

# %%
from google.colab.patches import cv2_imshow
data23 = cv2.imread('result/data23.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data23)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1F7990>

# %%
from google.colab.patches import cv2_imshow
data24 = cv2.imread('result/data24.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data24)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE185C50>

# %%
from google.colab.patches import cv2_imshow
data25 = cv2.imread('result/data25.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data25)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE18DA10>

# %%
from google.colab.patches import cv2_imshow
data26 = cv2.imread('result/data26.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data26)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE235E90>

# %%
from google.colab.patches import cv2_imshow
data27 = cv2.imread('result/data27.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data27)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FF3640D0>

# %%
from google.colab.patches import cv2_imshow
data28 = cv2.imread('result/data28.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data28)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1DEED0>

# %%
from google.colab.patches import cv2_imshow
data29 = cv2.imread('result/data29.jpg', cv2.IMREAD_UNCHANGED)

# %%
cv2_imshow(data29)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F43FE1930D0>
